# %%
import torch
import torch.nn.functional as F
import numpy as np                 # import numpy
import matplotlib.pyplot as plt    # import matplotlib
from torch.utils.data import Dataset, DataLoader,random_split
import torch.optim as optim
from tqdm import tqdm
import h5py
import scipy
from scipy.signal import find_peaks
from IPython.display import Image
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
import optuna

import utils
import Model
import Simulate_Dataset

# Set a random seed for PyTorch
seed = 42
torch.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False


use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

# %%
# dataset parameters
fs = 1000                     # sampling frequency in Hz
data_dur =  3*63                 # data duration in s
actpot_dur = 5                   # action potential length in ms
window_dur = 3                   # window dutation in s
C = 1                              # number of neurons
s = 40                              # number of appearance of each neuron in each window
x_mean = 2                         # code amplitude mean
x_std = 0.1                         # code amplitude std
noise_std = 0.1
snr = 20

K = int(actpot_dur * fs / 1000) # filter legnth
N = int(window_dur * fs)        # example duration
J = int(data_dur / window_dur)  # number of examples

# data parameters
data_hyp ={"J": J, "N": N, "K": K, "C": C, "s": s, "x_mean": x_mean,
           "x_std": x_std, "SNR": snr, "device": device}

print("filter length:", K)
print("example duration:", N)
print("number of examples:", J)
# Out:
# filter length: 5
# example duration: 3000
# number of examples: 63

# %%
# fill in the gaps
net_hyp = {"T": 200,                 # number of encoder unfolding
           "L": 10,                  # 1/L is the step size in the encoder
           "C": 1,                 # number of filters
           "K": 18,                  # legnth of the filters
           "lam": 0.2,
           "device": device
           }

net = Model.CRsAE1D(net_hyp)

# training parameters
train_hyp = {"batch_size": 8, "num_epochs": 12, "lr": 1e-2, "shuffle": True}
# criterion
criterion = torch.nn.MSELoss()
# optimizer
optimizer = optim.Adam(net.parameters(), lr=train_hyp["lr"], eps=1e-3)

# %%
snr_list = np.linspace(-10,50,13)
print(snr_list)
# Out:
# [-10.  -5.   0.   5.  10.  15.  20.  25.  30.  35.  40.  45.  50.]

# %%
def f1_score(label, pred):
  label = np.array(label.cpu())
  true_positives = np.sum((pred == 1) & (label == 1))
  all_positives = np.sum(label == 1)
  predicted_positives = np.sum(pred == 1)

  precision = true_positives / predicted_positives if predicted_positives > 0 else 0.0
  recall = true_positives / all_positives if all_positives > 0 else 0.0

  f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0
  return f1_score

def check_naive_classifiers(signal, label, k=10):
    dataset_behave = create_behave_dataset_matrix(signal,label,device = device)
    X = dataset_behave.data.cpu()
    y = dataset_behave.label.cpu()

    kf = KFold(n_splits=k, shuffle=False)
    test_accuracy_list = []
    print("running tuna study on metric")
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, shuffle=False)

        def objective(trial):
            # Define hyperparameter search space
            model_type = trial.suggest_categorical('model', ['svm_linear', 'logistic'])
            C = trial.suggest_float('C', 0.01, 100, log=True)

            if model_type.startswith('svm'):
                svm_classifier = svm.SVC(C=C, kernel='linear')
                svm_classifier.fit(X_train, y_train)
                y_val_pred = svm_classifier.predict(X_val)
                val_accuracy = f1_score(y_val, y_val_pred)
            else:
                logistic_classifier = LogisticRegression(C=C, max_iter=1000)
                logistic_classifier.fit(X_train, y_train)
                y_val_pred = logistic_classifier.predict(X_val)
                val_accuracy = f1_score(y_val, y_val_pred)

            return val_accuracy

        # Create an Optuna study
        study = optuna.create_study(direction='maximize')
        study.optimize(objective, n_trials=20)

        # Get the best trial
        best_trial = study.best_trial
        best_params = best_trial.params
        best_score = best_trial.value

        # Train the best model on the entire training set
        if best_params['model'].startswith('svm'):
            best_model = svm.SVC(C=best_params['C'], kernel=best_params['model'][1:])
        else:
            best_model = LogisticRegression(C=best_params['C'], max_iter=1000)
        best_model.fit(X_train, y_train)

        # Evaluate the model on the test set
        y_test_pred = best_model.predict(X_test)
        test_accuracy = f1_score(y_test, y_test_pred)

        print("Best Hyperparameters from Optuna:", best_params)
        print("Best Validation Set Accuracy:", best_score)
        print("Test Set Accuracy:", test_accuracy)
        test_accuracy_list.append(test_accuracy)

    return np.mean(test_accuracy_list)


class create_behave_dataset_matrix(Dataset):
    def __init__(self, x,label,device):
        self.label = label
        chunks = torch.split(x, 1, dim=1)
        # Concatenating the chunks along the first dimension
        self.data = x.T

    def __len__(self):
        return len(self.label)

    def __getitem__(self, idx):
        return  self.data[idx], self.label[idx]

# %%
#snr_list = [(10,0.15),(15,0.15),(20,0.1),(25,0.05),(30,0.05),(35,0.1),(40,0),(45,0),(50,0),(-10,0.9),(-5,0.5),(0,0.3),(5,0.25)]
snr_list = [(5,0.25)]

# %%
x_f1_score = []
y_f1_score = []
y_hat_f1_score = []
cur_snr_list = []
x_const = None

# %%
for itr in range(1):
  print(f"%%%%%%%%%%%%%%{itr}%%%%%%%%%%%%%%%%%")
  for cur_snr, cur_lam in snr_list:
    net_hyp = {"T": 200,                 # number of encoder unfolding
            "L": 10,                  # 1/L is the step size in the encoder
            "C": 2,                 # number of filters
            "K": 18,                  # legnth of the filters
            "lam": cur_lam,
            "device": device
            }
    data_hyp ={"J": J, "N": N, "K": K, "C": C, "s": s, "x_mean": x_mean,
            "x_std": x_std, "SNR": cur_snr, "device": device}
    dataset = Simulate_Dataset.SimulatedDataset1D(data_hyp,x_const,one_kernel = True)
    net = Model.CRsAE1D(net_hyp)
    net.load_state_dict(torch.load(f'pretrained_on_simulated_data\snr_{snr_list[0][0]}.pth'))
    with torch.no_grad():
      y,x,_,_ = dataset[:]
      x_const = x
      x = torch.sum(x, dim=1, keepdim=True)
      y_hat, x_hat = net(y)
      #utils.vis_data_est(y[1,0], y_hat[1,0])
      x_hat = torch.sum(x_hat, dim=1, keepdim=True)
      y = y.squeeze(dim = 1)
      b = x[0,0] > 0
      x = x.squeeze(dim = 1)
      y_hat = y_hat.squeeze(dim = 1)
      x_hat = x_hat.squeeze(dim = 1)
      padding_begining = 7
      padding_end = 10
      # Perform the padding
      padded_tensor = torch.cat([torch.zeros(padding_begining).to(device), torch.tensor(b),torch.zeros(padding_end).to(device)])
      modified_tensor = torch.zeros_like(padded_tensor).to(device)
      indices_of_ones = torch.nonzero(padded_tensor).squeeze()

      for index in indices_of_ones:
        modified_tensor[index-1:index+3] = 1



    x_accuracy = []
    y_accuracy = []
    y_hat_accuracy = []
    print(f"For SNR = {cur_snr}")
    print("On x")
    x_accuracy.append(check_naive_classifiers(x, b))
    print("On y")
    y_accuracy.append(check_naive_classifiers(y, modified_tensor))
    print("On y_hat")
    y_hat_accuracy.append(check_naive_classifiers(y_hat, modified_tensor))

    cur_snr_list.append(cur_snr)
    x_f1_score.append(max(x_accuracy))
    y_f1_score.append(max(y_accuracy))
    y_hat_f1_score.append(max(y_hat_accuracy))

  # reset x for new study
  x_const = None
# Out:
# %%%%%%%%%%%%%%0%%%%%%%%%%%%%%%%%
# C:\Users\yonatan.kle\AppData\Local\Temp\ipykernel_2396\3034526194.py:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   padded_tensor = torch.cat([torch.zeros(padding_begining).to(device), torch.tensor(b),torch.zeros(padding_end).to(device)])
# [I 2023-09-13 12:16:57,861] A new study created in memory with name: no-name-aa0dfed2-f19b-47cf-bde4-c9b8c5d34392
# [I 2023-09-13 12:16:57,870] Trial 0 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.5303915968800557}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:57,881] Trial 1 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.03893233500478464}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:57,894] Trial 2 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.06526483502925477}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:57,897] Trial 3 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.05549631228058489}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:57,897] Trial 4 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 1.1342669181890381}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:57,915] Trial 5 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.3629153462929092}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:57,915] Trial 6 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 9.274427284106379}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:57,915] Trial 7 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 17.27790131097189}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:57,932] Trial 8 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.04425510277061418}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:57,946] Trial 9 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.12622458431173975}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:57,948] Trial 10 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 2.2403504990065604}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:57,964] Trial 11 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.01039594305125683}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:57,977] Trial 12 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.3245805308540427}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:57,981] Trial 13 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 2.4598597563969786}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:57,981] Trial 14 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 81.7730857032969}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:57,998] Trial 15 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.326213113956319}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:57,998] Trial 16 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.1337588385972152}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,014] Trial 17 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.012478226694589015}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,032] Trial 18 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.8263556901820402}. Best is trial 0 with value: 1.0.
# For SNR = 5
# On x
# running tuna study on metric
# [I 2023-09-13 12:16:58,051] Trial 19 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.11655527695697267}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,051] A new study created in memory with name: no-name-3588466a-3924-4af6-99ff-743b1fe6cd9c
# [I 2023-09-13 12:16:58,063] Trial 0 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 24.336648837833653}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,066] Trial 1 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.010712671934963428}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,066] Trial 2 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 1.611908002631798}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,081] Trial 3 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.07220580307575497}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,097] Trial 4 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.050317731807543085}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,098] Trial 5 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 41.92051282581943}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,111] Trial 6 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.1681868330505408}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,116] Trial 7 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 1.6346725391508703}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,131] Trial 8 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 78.12191562032739}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,145] Trial 9 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 2.6449883458798253}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,148] Trial 10 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 12.9125127732854}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,164] Trial 11 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.01587646972507104}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,164] Trial 12 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.38049413272975824}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,182] Trial 13 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 7.8541328538672435}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,195] Trial 14 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.011878017080501131}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,198] Trial 15 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.5352343965826564}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,198] Trial 16 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 5.690407746237726}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,216] Trial 17 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 27.816758376879857}. Best is trial 0 with value: 1.0.
# Best Hyperparameters from Optuna: {'model': 'svm_linear', 'C': 0.5303915968800557}
# Best Validation Set Accuracy: 1.0
# Test Set Accuracy: 1.0
# [I 2023-09-13 12:16:58,232] Trial 18 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.6571887839794368}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,232] Trial 19 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 4.1585883163852815}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,246] A new study created in memory with name: no-name-c604b8f9-75f8-478f-8fc6-b833bc880362
# [I 2023-09-13 12:16:58,248] Trial 0 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.13285410532201283}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,262] Trial 1 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.014703989133521765}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,265] Trial 2 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.134884879306989}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,281] Trial 3 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 16.506658485427202}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,281] Trial 4 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.10028591055620507}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,298] Trial 5 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.5732576235408571}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,311] Trial 6 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.1812399631828625}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,314] Trial 7 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 81.64573458784692}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,314] Trial 8 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 1.8505460210583842}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,314] Trial 9 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 2.226156037927742}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,332] Trial 10 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.011955460361340974}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,346] Trial 11 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.07973208006225319}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,346] Trial 12 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.35427801216871424}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,363] Trial 13 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.05079135764804692}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,363] Trial 14 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.650680933835786}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,382] Trial 15 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.038753532601950975}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,394] Trial 16 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.22776350606305923}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,396] Trial 17 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.02616770752183274}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,413] Trial 18 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.13377646782472125}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,430] Trial 19 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.041262912832168507}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,430] A new study created in memory with name: no-name-1a82e67d-57a4-4907-a8b7-4c2ff7e1411e
# [I 2023-09-13 12:16:58,447] Trial 0 finished with value: 0.7499999999999999 and parameters: {'model': 'logistic', 'C': 0.09396760440419967}. Best is trial 0 with value: 0.7499999999999999.
# Best Hyperparameters from Optuna: {'model': 'svm_linear', 'C': 24.336648837833653}
# Best Validation Set Accuracy: 1.0
# Test Set Accuracy: 1.0
# Best Hyperparameters from Optuna: {'model': 'svm_linear', 'C': 0.13285410532201283}
# Best Validation Set Accuracy: 1.0
# Test Set Accuracy: 1.0
# [I 2023-09-13 12:16:58,447] Trial 1 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 10.929233301450505}. Best is trial 1 with value: 1.0.
# [I 2023-09-13 12:16:58,447] Trial 2 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 4.085211039360884}. Best is trial 1 with value: 1.0.
# [I 2023-09-13 12:16:58,463] Trial 3 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 97.43926473311868}. Best is trial 1 with value: 1.0.
# [I 2023-09-13 12:16:58,494] Trial 4 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.06441215719638076}. Best is trial 1 with value: 1.0.
# [I 2023-09-13 12:16:58,499] Trial 5 finished with value: 0.7499999999999999 and parameters: {'model': 'logistic', 'C': 0.09334940187137312}. Best is trial 1 with value: 1.0.
# [I 2023-09-13 12:16:58,499] Trial 6 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 1.2530295029136447}. Best is trial 1 with value: 1.0.
# [I 2023-09-13 12:16:58,513] Trial 7 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.011905271549017143}. Best is trial 1 with value: 1.0.
# [I 2023-09-13 12:16:58,513] Trial 8 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 48.75626136826852}. Best is trial 1 with value: 1.0.
# [I 2023-09-13 12:16:58,513] Trial 9 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 2.96212447399648}. Best is trial 1 with value: 1.0.
# [I 2023-09-13 12:16:58,544] Trial 10 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 15.868373795044615}. Best is trial 1 with value: 1.0.
# [I 2023-09-13 12:16:58,549] Trial 11 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 7.007112191242828}. Best is trial 1 with value: 1.0.
# [I 2023-09-13 12:16:58,549] Trial 12 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 12.20374328853024}. Best is trial 1 with value: 1.0.
# [I 2023-09-13 12:16:58,563] Trial 13 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 1.9999531039882286}. Best is trial 1 with value: 1.0.
# [I 2023-09-13 12:16:58,563] Trial 14 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.5675022484868916}. Best is trial 1 with value: 1.0.
# [I 2023-09-13 12:16:58,580] Trial 15 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 31.02169694354453}. Best is trial 1 with value: 1.0.
# [I 2023-09-13 12:16:58,580] Trial 16 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 5.801136052403237}. Best is trial 1 with value: 1.0.
# [I 2023-09-13 12:16:58,580] Trial 17 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 19.661292332864228}. Best is trial 1 with value: 1.0.
# [I 2023-09-13 12:16:58,613] Trial 18 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 4.6487693731407225}. Best is trial 1 with value: 1.0.
# [I 2023-09-13 12:16:58,613] Trial 19 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.7791906571963751}. Best is trial 1 with value: 1.0.
# [I 2023-09-13 12:16:58,613] A new study created in memory with name: no-name-8e8208a8-71e0-4010-aa89-ba57ab07005f
# [I 2023-09-13 12:16:58,631] Trial 0 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 9.564926028804985}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,631] Trial 1 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 3.9728903014504375}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,646] Trial 2 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 4.716302198276599}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,646] Trial 3 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 1.6181896577206707}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,664] Trial 4 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 56.846247280891525}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,664] Trial 5 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 3.4898043723628085}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,680] Trial 6 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.17598758497189299}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,680] Trial 7 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.11014700970922138}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,696] Trial 8 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.02936807473507601}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,696] Trial 9 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.03721588359133354}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,714] Trial 10 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 33.89050686766166}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,730] Trial 11 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 10.384257071841859}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,730] Trial 12 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.7110659290005565}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,748] Trial 13 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 15.235588007875435}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,766] Trial 14 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 87.1268015300731}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,782] Trial 15 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 14.243640231311012}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,782] Trial 16 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.8540933135318652}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,797] Trial 17 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 4.062095924423984}. Best is trial 0 with value: 1.0.
# Best Hyperparameters from Optuna: {'model': 'svm_linear', 'C': 10.929233301450505}
# Best Validation Set Accuracy: 1.0
# Test Set Accuracy: 1.0
# [I 2023-09-13 12:16:58,815] Trial 18 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 21.21225657169608}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,830] Trial 19 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 6.697230651128318}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,830] A new study created in memory with name: no-name-2723ee03-059a-4ec1-a2d8-d12cd797e5ac
# [I 2023-09-13 12:16:58,830] Trial 0 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.5298890540098783}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,847] Trial 1 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 34.96492262135624}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,863] Trial 2 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.07739986215534625}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,863] Trial 3 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 5.039732974452103}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,880] Trial 4 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.020105666557924416}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,897] Trial 5 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.6000059745145571}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,897] Trial 6 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.026216298797649546}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,914] Trial 7 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 17.035677457286987}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,930] Trial 8 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.5235199915454825}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,930] Trial 9 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.06870176270657484}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,946] Trial 10 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 88.62148131919513}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,963] Trial 11 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 3.494149155892322}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,980] Trial 12 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 32.51579958701812}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:58,997] Trial 13 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 2.390906560643595}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,013] Trial 14 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.4606281803339621}. Best is trial 0 with value: 1.0.
# Best Hyperparameters from Optuna: {'model': 'svm_linear', 'C': 9.564926028804985}
# Best Validation Set Accuracy: 1.0
# Test Set Accuracy: 1.0
# [I 2023-09-13 12:16:59,030] Trial 15 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 12.379312773312135}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,030] Trial 16 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 1.402520513718736}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,047] Trial 17 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 96.23979552373252}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,070] Trial 18 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 7.432993347192151}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,081] Trial 19 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 1.2470937971582303}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,081] A new study created in memory with name: no-name-f0d4cd3d-a46b-4713-8a07-61dcb23512fd
# [I 2023-09-13 12:16:59,081] Trial 0 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 5.184296032388623}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,097] Trial 1 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 5.009647112326465}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,113] Trial 2 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.07966422089685139}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,114] Trial 3 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 10.666311411570483}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,130] Trial 4 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.5589279154096954}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,130] Trial 5 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 23.284385848343643}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,130] Trial 6 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.044266001149602406}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,147] Trial 7 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.24941807308032363}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,164] Trial 8 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 1.0844014228503203}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,165] Trial 9 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 3.197569270534365}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,165] Trial 10 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 59.62503955785862}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,181] Trial 11 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 4.429343366552518}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,199] Trial 12 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 2.818483737301575}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,219] Trial 13 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 97.03452233726625}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,233] Trial 14 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 11.25615373061961}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,245] Trial 15 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.013503308721713318}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,247] Trial 16 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 1.3792128137080544}. Best is trial 0 with value: 1.0.
# Best Hyperparameters from Optuna: {'model': 'svm_linear', 'C': 0.5298890540098783}
# Best Validation Set Accuracy: 1.0
# Test Set Accuracy: 1.0
# [I 2023-09-13 12:16:59,264] Trial 17 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 8.037038798671896}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,280] Trial 18 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 23.597661097905917}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,295] Trial 19 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 2.2521068096514005}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,297] A new study created in memory with name: no-name-546ef034-569a-4def-9f5a-cce63b872ebe
# [I 2023-09-13 12:16:59,312] Trial 0 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 1.4123966580738403}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,315] Trial 1 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 13.726515580630782}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,315] Trial 2 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.18688451709414325}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,332] Trial 3 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 2.8097403110997843}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,332] Trial 4 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.21324512006525742}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,348] Trial 5 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 6.696394770197707}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,362] Trial 6 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 10.354000511652817}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,363] Trial 7 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 18.706150093749677}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,380] Trial 8 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.059561241791979795}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,380] Trial 9 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 15.577350964522799}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,398] Trial 10 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.012384930971378043}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,415] Trial 11 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 88.22721843073076}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,415] Trial 12 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 1.188376051071846}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,430] Trial 13 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 1.4273587120794515}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,448] Trial 14 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 3.1455145664365634}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,465] Trial 15 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.43310470901457526}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,482] Trial 16 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 43.1408704886175}. Best is trial 0 with value: 1.0.
# Best Hyperparameters from Optuna: {'model': 'svm_linear', 'C': 5.184296032388623}
# Best Validation Set Accuracy: 1.0
# Test Set Accuracy: 1.0
# [I 2023-09-13 12:16:59,495] Trial 17 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 4.760872528077752}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,512] Trial 18 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 26.09530456925055}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,514] Trial 19 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 7.297286608224067}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,530] A new study created in memory with name: no-name-7ac0a496-cc4f-42e9-9214-21aa49197526
# [I 2023-09-13 12:16:59,547] Trial 0 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 2.342415284160474}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,547] Trial 1 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 1.7215873798297197}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,563] Trial 2 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 55.18738864983281}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,566] Trial 3 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 1.717361356919449}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,566] Trial 4 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.026982544987224855}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,582] Trial 5 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.014352398052544079}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,582] Trial 6 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 21.45728464893928}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,597] Trial 7 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 1.0936237546093266}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,598] Trial 8 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 1.1599391132808987}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,614] Trial 9 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 4.644642996777275}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,631] Trial 10 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.1914684770793981}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,631] Trial 11 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 6.216987760530554}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,645] Trial 12 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.1956271037573662}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,649] Trial 13 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 8.330305196885925}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,664] Trial 14 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.3232072488799086}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,664] Trial 15 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 71.4844502837864}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,681] Trial 16 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 4.2565354081273465}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,698] Trial 17 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 16.881529552075293}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,698] Trial 18 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.4058449787096061}. Best is trial 0 with value: 1.0.
# Best Hyperparameters from Optuna: {'model': 'logistic', 'C': 1.4123966580738403}
# Best Validation Set Accuracy: 1.0
# Test Set Accuracy: 1.0
# [I 2023-09-13 12:16:59,714] Trial 19 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 2.127724981650304}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,731] A new study created in memory with name: no-name-da1dbfc3-c5a1-4a12-a33d-809a2b61c597
# [I 2023-09-13 12:16:59,731] Trial 0 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.17640526747650792}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,747] Trial 1 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 2.8786556674726103}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,748] Trial 2 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 44.417586260006196}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,765] Trial 3 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 56.72088339108726}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,781] Trial 4 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.03378722458652558}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,781] Trial 5 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.025920585499811227}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,795] Trial 6 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 4.4715087823512345}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,798] Trial 7 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.17251927798699931}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,815] Trial 8 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.02541766326267911}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,815] Trial 9 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 7.556841355292193}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,832] Trial 10 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.34819104350480745}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,832] Trial 11 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 1.2221382720858127}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,849] Trial 12 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.19735913914350403}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,849] Trial 13 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 1.9888234352969605}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,865] Trial 14 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.5078624750456864}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,865] Trial 15 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.09409757953895578}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,881] Trial 16 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.922848369764732}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,898] Trial 17 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.011150094033533781}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,914] Trial 18 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 10.5596393053019}. Best is trial 0 with value: 1.0.
# [I 2023-09-13 12:16:59,914] Trial 19 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.497682666246517}. Best is trial 0 with value: 1.0.
# Best Hyperparameters from Optuna: {'model': 'logistic', 'C': 2.342415284160474}
# Best Validation Set Accuracy: 1.0
# Test Set Accuracy: 1.0
# Best Hyperparameters from Optuna: {'model': 'svm_linear', 'C': 0.17640526747650792}
# Best Validation Set Accuracy: 1.0
# Test Set Accuracy: 1.0
# On y
# running tuna study on metric
# [I 2023-09-13 12:16:59,932] A new study created in memory with name: no-name-98cd8981-19e2-4af6-8dad-9ea274f57e6d
# [I 2023-09-13 12:16:59,948] Trial 0 finished with value: 0.6206896551724138 and parameters: {'model': 'logistic', 'C': 0.5971358048302133}. Best is trial 0 with value: 0.6206896551724138.
# [I 2023-09-13 12:16:59,948] Trial 1 finished with value: 0.4615384615384615 and parameters: {'model': 'logistic', 'C': 0.23623011895883134}. Best is trial 0 with value: 0.6206896551724138.
# [I 2023-09-13 12:16:59,966] Trial 2 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.02010273510116578}. Best is trial 0 with value: 0.6206896551724138.
# [I 2023-09-13 12:16:59,981] Trial 3 finished with value: 0.6206896551724138 and parameters: {'model': 'svm_linear', 'C': 0.11693832759783095}. Best is trial 0 with value: 0.6206896551724138.
# [I 2023-09-13 12:16:59,998] Trial 4 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.010112460524861094}. Best is trial 0 with value: 0.6206896551724138.
# [I 2023-09-13 12:17:00,030] Trial 5 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 0.03055986539212845}. Best is trial 0 with value: 0.6206896551724138.
# [I 2023-09-13 12:17:00,036] Trial 6 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.019422552758405306}. Best is trial 0 with value: 0.6206896551724138.
# [I 2023-09-13 12:17:00,047] Trial 7 finished with value: 0.7647058823529412 and parameters: {'model': 'logistic', 'C': 3.1192886398106903}. Best is trial 7 with value: 0.7647058823529412.
# [I 2023-09-13 12:17:00,047] Trial 8 finished with value: 0.4615384615384615 and parameters: {'model': 'logistic', 'C': 0.2083105859909198}. Best is trial 7 with value: 0.7647058823529412.
# [I 2023-09-13 12:17:00,086] Trial 9 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 0.02267635103303773}. Best is trial 7 with value: 0.7647058823529412.
# [I 2023-09-13 12:17:00,126] Trial 10 finished with value: 0.7222222222222223 and parameters: {'model': 'svm_linear', 'C': 7.619324600493288}. Best is trial 7 with value: 0.7647058823529412.
# [I 2023-09-13 12:17:00,166] Trial 11 finished with value: 0.7567567567567567 and parameters: {'model': 'svm_linear', 'C': 8.05930652657571}. Best is trial 7 with value: 0.7647058823529412.
# [I 2023-09-13 12:17:00,200] Trial 12 finished with value: 0.7222222222222223 and parameters: {'model': 'svm_linear', 'C': 6.4733361001052305}. Best is trial 7 with value: 0.7647058823529412.
# [I 2023-09-13 12:17:00,246] Trial 13 finished with value: 0.8108108108108107 and parameters: {'model': 'svm_linear', 'C': 48.07850000438678}. Best is trial 13 with value: 0.8108108108108107.
# [I 2023-09-13 12:17:00,284] Trial 14 finished with value: 0.8205128205128205 and parameters: {'model': 'logistic', 'C': 83.51537926931896}. Best is trial 14 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:00,344] Trial 15 finished with value: 0.8108108108108107 and parameters: {'model': 'svm_linear', 'C': 64.86997262668385}. Best is trial 14 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:00,414] Trial 16 finished with value: 0.7894736842105262 and parameters: {'model': 'svm_linear', 'C': 86.60253162380825}. Best is trial 14 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:00,443] Trial 17 finished with value: 0.7894736842105262 and parameters: {'model': 'logistic', 'C': 30.632919788493552}. Best is trial 14 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:00,465] Trial 18 finished with value: 0.7894736842105262 and parameters: {'model': 'logistic', 'C': 25.009819850718795}. Best is trial 14 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:00,529] Trial 19 finished with value: 0.7894736842105262 and parameters: {'model': 'svm_linear', 'C': 94.07877679153047}. Best is trial 14 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:00,561] A new study created in memory with name: no-name-122f3ec0-8559-4309-8e7b-40d15521a8e9
# [I 2023-09-13 12:17:00,569] Trial 0 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.03249404952503626}. Best is trial 0 with value: 0.0.
# [I 2023-09-13 12:17:00,645] Trial 1 finished with value: 0.6666666666666667 and parameters: {'model': 'svm_linear', 'C': 42.13379800225801}. Best is trial 1 with value: 0.6666666666666667.
# [I 2023-09-13 12:17:00,679] Trial 2 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 0.016489698569631513}. Best is trial 1 with value: 0.6666666666666667.
# [I 2023-09-13 12:17:00,700] Trial 3 finished with value: 0.8108108108108107 and parameters: {'model': 'svm_linear', 'C': 0.926325765329096}. Best is trial 3 with value: 0.8108108108108107.
# Best Hyperparameters from Optuna: {'model': 'logistic', 'C': 83.51537926931896}
# Best Validation Set Accuracy: 0.8205128205128205
# Test Set Accuracy: 0.7142857142857143
# [I 2023-09-13 12:17:00,762] Trial 4 finished with value: 0.6666666666666667 and parameters: {'model': 'svm_linear', 'C': 35.11887713295644}. Best is trial 3 with value: 0.8108108108108107.
# [I 2023-09-13 12:17:00,782] Trial 5 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.015188438544353759}. Best is trial 3 with value: 0.8108108108108107.
# [I 2023-09-13 12:17:00,782] Trial 6 finished with value: 0.5714285714285715 and parameters: {'model': 'logistic', 'C': 0.2603298559924451}. Best is trial 3 with value: 0.8108108108108107.
# [I 2023-09-13 12:17:00,816] Trial 7 finished with value: 0.8205128205128205 and parameters: {'model': 'logistic', 'C': 20.749173851102263}. Best is trial 7 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:00,832] Trial 8 finished with value: 0.7428571428571429 and parameters: {'model': 'svm_linear', 'C': 0.49071371629102}. Best is trial 7 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:00,897] Trial 9 finished with value: 0.6666666666666667 and parameters: {'model': 'svm_linear', 'C': 31.28623985013812}. Best is trial 7 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:00,922] Trial 10 finished with value: 0.7567567567567567 and parameters: {'model': 'logistic', 'C': 6.209438653437032}. Best is trial 7 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:00,939] Trial 11 finished with value: 0.7272727272727274 and parameters: {'model': 'logistic', 'C': 2.463798335197088}. Best is trial 7 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:00,968] Trial 12 finished with value: 0.8095238095238095 and parameters: {'model': 'svm_linear', 'C': 5.722151174120566}. Best is trial 7 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:00,982] Trial 13 finished with value: 0.6874999999999999 and parameters: {'model': 'logistic', 'C': 1.3493021646686556}. Best is trial 7 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:01,047] Trial 14 finished with value: 0.65 and parameters: {'model': 'svm_linear', 'C': 78.51535380628592}. Best is trial 7 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:01,074] Trial 15 finished with value: 0.7567567567567567 and parameters: {'model': 'logistic', 'C': 10.130599110212032}. Best is trial 7 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:01,103] Trial 16 finished with value: 0.7272727272727274 and parameters: {'model': 'svm_linear', 'C': 0.286986080573874}. Best is trial 7 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:01,115] Trial 17 finished with value: 0.7272727272727274 and parameters: {'model': 'logistic', 'C': 1.7598419488112211}. Best is trial 7 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:01,153] Trial 18 finished with value: 0.75 and parameters: {'model': 'svm_linear', 'C': 11.767686850687415}. Best is trial 7 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:01,172] Trial 19 finished with value: 0.7272727272727274 and parameters: {'model': 'logistic', 'C': 3.1104570333893893}. Best is trial 7 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:01,194] A new study created in memory with name: no-name-cbe51dec-72a4-4cca-b230-66e18e9baf06
# [I 2023-09-13 12:17:01,199] Trial 0 finished with value: 0.7096774193548387 and parameters: {'model': 'logistic', 'C': 1.031513523145449}. Best is trial 0 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:01,199] Trial 1 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.011104745091424943}. Best is trial 0 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:01,219] Trial 2 finished with value: 0.6666666666666666 and parameters: {'model': 'logistic', 'C': 0.5745869627346645}. Best is trial 0 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:01,232] Trial 3 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.011756140546215772}. Best is trial 0 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:01,249] Trial 4 finished with value: 0.8205128205128205 and parameters: {'model': 'svm_linear', 'C': 7.734724081639965}. Best is trial 4 with value: 0.8205128205128205.
# [I 2023-09-13 12:17:01,266] Trial 5 finished with value: 0.85 and parameters: {'model': 'logistic', 'C': 21.83215122321493}. Best is trial 5 with value: 0.85.
# [I 2023-09-13 12:17:01,304] Trial 6 finished with value: 0.8205128205128205 and parameters: {'model': 'svm_linear', 'C': 1.8201833151618658}. Best is trial 5 with value: 0.85.
# [I 2023-09-13 12:17:01,327] Trial 7 finished with value: 0.6666666666666666 and parameters: {'model': 'svm_linear', 'C': 0.12561232473672138}. Best is trial 5 with value: 0.85.
# [I 2023-09-13 12:17:01,357] Trial 8 finished with value: 0.8205128205128205 and parameters: {'model': 'svm_linear', 'C': 10.97299862170911}. Best is trial 5 with value: 0.85.
# [I 2023-09-13 12:17:01,365] Trial 9 finished with value: 0.7499999999999999 and parameters: {'model': 'svm_linear', 'C': 0.1407569990427703}. Best is trial 5 with value: 0.85.
# Best Hyperparameters from Optuna: {'model': 'logistic', 'C': 20.749173851102263}
# Best Validation Set Accuracy: 0.8205128205128205
# Test Set Accuracy: 0.7777777777777778
# [I 2023-09-13 12:17:01,406] Trial 10 finished with value: 0.8095238095238095 and parameters: {'model': 'logistic', 'C': 84.21406050857874}. Best is trial 5 with value: 0.85.
# [I 2023-09-13 12:17:01,464] Trial 11 finished with value: 0.8000000000000002 and parameters: {'model': 'svm_linear', 'C': 20.095424053671497}. Best is trial 5 with value: 0.85.
# [I 2023-09-13 12:17:01,500] Trial 12 finished with value: 0.8205128205128205 and parameters: {'model': 'svm_linear', 'C': 9.35672663788228}. Best is trial 5 with value: 0.85.
# [I 2023-09-13 12:17:01,529] Trial 13 finished with value: 0.8095238095238095 and parameters: {'model': 'logistic', 'C': 67.09260498544096}. Best is trial 5 with value: 0.85.
# [I 2023-09-13 12:17:01,561] Trial 14 finished with value: 0.8205128205128205 and parameters: {'model': 'svm_linear', 'C': 4.62603397027781}. Best is trial 5 with value: 0.85.
# [I 2023-09-13 12:17:01,584] Trial 15 finished with value: 0.8292682926829269 and parameters: {'model': 'logistic', 'C': 28.02392246161437}. Best is trial 5 with value: 0.85.
# [I 2023-09-13 12:17:01,608] Trial 16 finished with value: 0.8095238095238095 and parameters: {'model': 'logistic', 'C': 35.0649399554619}. Best is trial 5 with value: 0.85.
# [I 2023-09-13 12:17:01,631] Trial 17 finished with value: 0.8095238095238095 and parameters: {'model': 'logistic', 'C': 32.818722645170304}. Best is trial 5 with value: 0.85.
# [I 2023-09-13 12:17:01,658] Trial 18 finished with value: 0.8095238095238095 and parameters: {'model': 'logistic', 'C': 95.07119962470863}. Best is trial 5 with value: 0.85.
# [I 2023-09-13 12:17:01,666] Trial 19 finished with value: 0.85 and parameters: {'model': 'logistic', 'C': 16.548453751618744}. Best is trial 5 with value: 0.85.
# [I 2023-09-13 12:17:01,697] A new study created in memory with name: no-name-1386a5cd-f555-48dc-b013-3d3edd0f0fad
# [I 2023-09-13 12:17:01,702] Trial 0 finished with value: 0.33333333333333337 and parameters: {'model': 'logistic', 'C': 0.13296479631264732}. Best is trial 0 with value: 0.33333333333333337.
# [I 2023-09-13 12:17:01,716] Trial 1 finished with value: 0.8333333333333334 and parameters: {'model': 'logistic', 'C': 4.054044975071367}. Best is trial 1 with value: 0.8333333333333334.
# [I 2023-09-13 12:17:01,731] Trial 2 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.07090334136180895}. Best is trial 1 with value: 0.8333333333333334.
# [I 2023-09-13 12:17:01,750] Trial 3 finished with value: 0.8421052631578948 and parameters: {'model': 'svm_linear', 'C': 4.718729404242466}. Best is trial 3 with value: 0.8421052631578948.
# [I 2023-09-13 12:17:01,781] Trial 4 finished with value: 0.6206896551724138 and parameters: {'model': 'svm_linear', 'C': 0.0840132312261313}. Best is trial 3 with value: 0.8421052631578948.
# [I 2023-09-13 12:17:01,813] Trial 5 finished with value: 0.8108108108108107 and parameters: {'model': 'svm_linear', 'C': 14.877881408384258}. Best is trial 3 with value: 0.8421052631578948.
# Best Hyperparameters from Optuna: {'model': 'logistic', 'C': 21.83215122321493}
# Best Validation Set Accuracy: 0.85
# ...
# [I 2023-09-13 12:17:09,777] Trial 0 finished with value: 0.18181818181818182 and parameters: {'model': 'svm_linear', 'C': 0.07276529783153751}. Best is trial 0 with value: 0.18181818181818182.
# [I 2023-09-13 12:17:09,813] Trial 1 finished with value: 0.6470588235294117 and parameters: {'model': 'svm_linear', 'C': 8.071383070881158}. Best is trial 1 with value: 0.6470588235294117.
# [I 2023-09-13 12:17:09,838] Trial 2 finished with value: 0.6 and parameters: {'model': 'svm_linear', 'C': 1.1484940214708084}. Best is trial 1 with value: 0.6470588235294117.
# [I 2023-09-13 12:17:09,858] Trial 3 finished with value: 0.6666666666666666 and parameters: {'model': 'logistic', 'C': 1.1441231748858152}. Best is trial 3 with value: 0.6666666666666666.
# [I 2023-09-13 12:17:09,874] Trial 4 finished with value: 0.7096774193548387 and parameters: {'model': 'logistic', 'C': 1.3674551524873018}. Best is trial 4 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:09,887] Trial 5 finished with value: 0.5714285714285715 and parameters: {'model': 'logistic', 'C': 0.5387268739969262}. Best is trial 4 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:09,892] Trial 6 finished with value: 0.09523809523809523 and parameters: {'model': 'logistic', 'C': 0.14487637147896873}. Best is trial 4 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:09,921] Trial 7 finished with value: 0.6 and parameters: {'model': 'svm_linear', 'C': 0.6813032745471156}. Best is trial 4 with value: 0.7096774193548387.
# Best Hyperparameters from Optuna: {'model': 'logistic', 'C': 2.9562389669516187}
# Best Validation Set Accuracy: 0.6666666666666667
# Test Set Accuracy: 0.7096774193548387
# [I 2023-09-13 12:17:09,939] Trial 8 finished with value: 0.6285714285714286 and parameters: {'model': 'logistic', 'C': 31.088045083513094}. Best is trial 4 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:09,974] Trial 9 finished with value: 0.6285714285714286 and parameters: {'model': 'svm_linear', 'C': 5.7811959497652525}. Best is trial 4 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:09,987] Trial 10 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.013193255476193773}. Best is trial 4 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,009] Trial 11 finished with value: 0.6874999999999999 and parameters: {'model': 'logistic', 'C': 3.1226943090101162}. Best is trial 4 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,031] Trial 12 finished with value: 0.6285714285714286 and parameters: {'model': 'logistic', 'C': 67.01459163135439}. Best is trial 4 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,039] Trial 13 finished with value: 0.6666666666666667 and parameters: {'model': 'logistic', 'C': 3.977623600062513}. Best is trial 4 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,074] Trial 14 finished with value: 0.6285714285714286 and parameters: {'model': 'logistic', 'C': 14.279938990629187}. Best is trial 4 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,094] Trial 15 finished with value: 0.6874999999999999 and parameters: {'model': 'logistic', 'C': 2.844400832023963}. Best is trial 4 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,117] Trial 16 finished with value: 0.6285714285714286 and parameters: {'model': 'logistic', 'C': 17.99639881979804}. Best is trial 4 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,129] Trial 17 finished with value: 0.6874999999999999 and parameters: {'model': 'logistic', 'C': 2.3448318608954635}. Best is trial 4 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,143] Trial 18 finished with value: 0.2608695652173913 and parameters: {'model': 'logistic', 'C': 0.24875293458254352}. Best is trial 4 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,176] Trial 19 finished with value: 0.6285714285714286 and parameters: {'model': 'logistic', 'C': 96.47401198589631}. Best is trial 4 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,194] A new study created in memory with name: no-name-7cac7ef4-832f-42c1-a51c-bf0b97084e21
# [I 2023-09-13 12:17:10,208] Trial 0 finished with value: 0.6206896551724138 and parameters: {'model': 'logistic', 'C': 0.7750230317844279}. Best is trial 0 with value: 0.6206896551724138.
# [I 2023-09-13 12:17:10,215] Trial 1 finished with value: 0.33333333333333337 and parameters: {'model': 'logistic', 'C': 0.3100550339238533}. Best is trial 0 with value: 0.6206896551724138.
# [I 2023-09-13 12:17:10,229] Trial 2 finished with value: 0.7096774193548387 and parameters: {'model': 'logistic', 'C': 2.081427320236832}. Best is trial 2 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,239] Trial 3 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.1618511734668118}. Best is trial 2 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,256] Trial 4 finished with value: 0.6666666666666666 and parameters: {'model': 'svm_linear', 'C': 0.22838509488519904}. Best is trial 2 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,274] Trial 5 finished with value: 0.18181818181818182 and parameters: {'model': 'logistic', 'C': 0.23628759678111827}. Best is trial 2 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,289] Trial 6 finished with value: 0.18181818181818182 and parameters: {'model': 'svm_linear', 'C': 0.07792761065522993}. Best is trial 2 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,324] Trial 7 finished with value: 0.6666666666666666 and parameters: {'model': 'svm_linear', 'C': 0.3615871631982875}. Best is trial 2 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,345] Trial 8 finished with value: 0.6666666666666665 and parameters: {'model': 'logistic', 'C': 59.40762254318447}. Best is trial 2 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,369] Trial 9 finished with value: 0.6451612903225806 and parameters: {'model': 'svm_linear', 'C': 0.7129472401755662}. Best is trial 2 with value: 0.7096774193548387.
# Best Hyperparameters from Optuna: {'model': 'logistic', 'C': 1.3674551524873018}
# Best Validation Set Accuracy: 0.7096774193548387
# Test Set Accuracy: 0.5882352941176471
# [I 2023-09-13 12:17:10,382] Trial 10 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.019657668991231926}. Best is trial 2 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,414] Trial 11 finished with value: 0.625 and parameters: {'model': 'svm_linear', 'C': 5.276074521357233}. Best is trial 2 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,447] Trial 12 finished with value: 0.625 and parameters: {'model': 'svm_linear', 'C': 3.4284726978185196}. Best is trial 2 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,480] Trial 13 finished with value: 0.625 and parameters: {'model': 'svm_linear', 'C': 2.767547165778952}. Best is trial 2 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,497] Trial 14 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.046355017875878445}. Best is trial 2 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,521] Trial 15 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 0.012867562853791755}. Best is trial 2 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,541] Trial 16 finished with value: 0.7096774193548387 and parameters: {'model': 'logistic', 'C': 1.4548479472842497}. Best is trial 2 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,557] Trial 17 finished with value: 0.6857142857142857 and parameters: {'model': 'logistic', 'C': 11.255325428873352}. Best is trial 2 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,574] Trial 18 finished with value: 0.6666666666666666 and parameters: {'model': 'logistic', 'C': 0.9292061212152377}. Best is trial 2 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,590] Trial 19 finished with value: 0.7096774193548387 and parameters: {'model': 'logistic', 'C': 1.9634776572390356}. Best is trial 2 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,608] A new study created in memory with name: no-name-06d8dbaf-60c2-4d89-bbeb-6a7a9a3da280
# [I 2023-09-13 12:17:10,641] Trial 0 finished with value: 0.631578947368421 and parameters: {'model': 'logistic', 'C': 69.21632578680124}. Best is trial 0 with value: 0.631578947368421.
# [I 2023-09-13 12:17:10,648] Trial 1 finished with value: 0.5714285714285715 and parameters: {'model': 'logistic', 'C': 0.3267068274002665}. Best is trial 0 with value: 0.631578947368421.
# [I 2023-09-13 12:17:10,680] Trial 2 finished with value: 0.625 and parameters: {'model': 'svm_linear', 'C': 2.321618243694037}. Best is trial 0 with value: 0.631578947368421.
# [I 2023-09-13 12:17:10,689] Trial 3 finished with value: 0.6666666666666667 and parameters: {'model': 'logistic', 'C': 3.5465104933394858}. Best is trial 3 with value: 0.6666666666666667.
# [I 2023-09-13 12:17:10,708] Trial 4 finished with value: 0.2608695652173913 and parameters: {'model': 'logistic', 'C': 0.2345643859348902}. Best is trial 3 with value: 0.6666666666666667.
# [I 2023-09-13 12:17:10,741] Trial 5 finished with value: 0.2608695652173913 and parameters: {'model': 'svm_linear', 'C': 0.08303214842940361}. Best is trial 3 with value: 0.6666666666666667.
# [I 2023-09-13 12:17:10,766] Trial 6 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 0.049485046348573966}. Best is trial 3 with value: 0.6666666666666667.
# [I 2023-09-13 12:17:10,793] Trial 7 finished with value: 0.6874999999999999 and parameters: {'model': 'svm_linear', 'C': 1.3744621479714538}. Best is trial 7 with value: 0.6874999999999999.
# Best Hyperparameters from Optuna: {'model': 'logistic', 'C': 2.081427320236832}
# Best Validation Set Accuracy: 0.7096774193548387
# Test Set Accuracy: 0.7804878048780487
# [I 2023-09-13 12:17:10,806] Trial 8 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 0.013559502724657757}. Best is trial 7 with value: 0.6874999999999999.
# [I 2023-09-13 12:17:10,830] Trial 9 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.017162226851899633}. Best is trial 7 with value: 0.6874999999999999.
# [I 2023-09-13 12:17:10,873] Trial 10 finished with value: 0.6666666666666667 and parameters: {'model': 'svm_linear', 'C': 8.94381184616404}. Best is trial 7 with value: 0.6874999999999999.
# [I 2023-09-13 12:17:10,890] Trial 11 finished with value: 0.7096774193548387 and parameters: {'model': 'logistic', 'C': 1.5288136060189434}. Best is trial 11 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,908] Trial 12 finished with value: 0.6666666666666666 and parameters: {'model': 'logistic', 'C': 0.8024796587840137}. Best is trial 11 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,945] Trial 13 finished with value: 0.7096774193548387 and parameters: {'model': 'svm_linear', 'C': 0.9364768009056252}. Best is trial 11 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,963] Trial 14 finished with value: 0.6666666666666667 and parameters: {'model': 'logistic', 'C': 6.780087999809968}. Best is trial 11 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:10,993] Trial 15 finished with value: 0.6666666666666666 and parameters: {'model': 'svm_linear', 'C': 0.6064686938828759}. Best is trial 11 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:11,007] Trial 16 finished with value: 0.2608695652173913 and parameters: {'model': 'logistic', 'C': 0.23005912171969917}. Best is trial 11 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:11,042] Trial 17 finished with value: 0.6874999999999999 and parameters: {'model': 'svm_linear', 'C': 1.195745146533953}. Best is trial 11 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:11,072] Trial 18 finished with value: 0.6470588235294117 and parameters: {'model': 'logistic', 'C': 12.974093565282905}. Best is trial 11 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:11,106] Trial 19 finished with value: 0.6666666666666667 and parameters: {'model': 'svm_linear', 'C': 3.0105142741902595}. Best is trial 11 with value: 0.7096774193548387.
# [I 2023-09-13 12:17:11,126] A new study created in memory with name: no-name-8a22ce84-fc6b-4cce-8b7f-5a2c824c7e73
# [I 2023-09-13 12:17:11,150] Trial 0 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 0.023633773737927855}. Best is trial 0 with value: 0.0.
# [I 2023-09-13 12:17:11,157] Trial 1 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.053956059603469775}. Best is trial 0 with value: 0.0.
# [I 2023-09-13 12:17:11,174] Trial 2 finished with value: 0.4 and parameters: {'model': 'logistic', 'C': 3.0207675852967037}. Best is trial 2 with value: 0.4.
# [I 2023-09-13 12:17:11,207] Trial 3 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 0.3812756031043219}. Best is trial 2 with value: 0.4.
# [I 2023-09-13 12:17:11,216] Trial 4 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.012342456928559599}. Best is trial 2 with value: 0.4.
# [I 2023-09-13 12:17:11,238] Trial 5 finished with value: 0.6666666666666666 and parameters: {'model': 'logistic', 'C': 64.73780655653773}. Best is trial 5 with value: 0.6666666666666666.
# [I 2023-09-13 12:17:11,244] Trial 6 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.07664976015472919}. Best is trial 5 with value: 0.6666666666666666.
# [I 2023-09-13 12:17:11,257] Trial 7 finished with value: 0.4 and parameters: {'model': 'logistic', 'C': 2.415369850310563}. Best is trial 5 with value: 0.6666666666666666.
# [I 2023-09-13 12:17:11,296] Trial 8 finished with value: 0.5714285714285715 and parameters: {'model': 'svm_linear', 'C': 3.8558559769888756}. Best is trial 5 with value: 0.6666666666666666.
# Best Hyperparameters from Optuna: {'model': 'logistic', 'C': 1.5288136060189434}
# Best Validation Set Accuracy: 0.7096774193548387
# Test Set Accuracy: 0.6
# [I 2023-09-13 12:17:11,357] Trial 9 finished with value: 0.5714285714285715 and parameters: {'model': 'svm_linear', 'C': 20.154077511083237}. Best is trial 5 with value: 0.6666666666666666.
# [I 2023-09-13 12:17:11,397] Trial 10 finished with value: 0.6666666666666666 and parameters: {'model': 'logistic', 'C': 79.60942610675606}. Best is trial 5 with value: 0.6666666666666666.
# [I 2023-09-13 12:17:11,422] Trial 11 finished with value: 0.6666666666666666 and parameters: {'model': 'logistic', 'C': 67.72874651996577}. Best is trial 5 with value: 0.6666666666666666.
# [I 2023-09-13 12:17:11,442] Trial 12 finished with value: 0.6666666666666666 and parameters: {'model': 'logistic', 'C': 85.39495719581784}. Best is trial 5 with value: 0.6666666666666666.
# [I 2023-09-13 12:17:11,459] Trial 13 finished with value: 0.6666666666666666 and parameters: {'model': 'logistic', 'C': 25.523246485740156}. Best is trial 5 with value: 0.6666666666666666.
# [I 2023-09-13 12:17:11,498] Trial 14 finished with value: 0.6666666666666666 and parameters: {'model': 'logistic', 'C': 15.058830984054268}. Best is trial 5 with value: 0.6666666666666666.
# [I 2023-09-13 12:17:11,524] Trial 15 finished with value: 0.6666666666666666 and parameters: {'model': 'logistic', 'C': 88.60298787153639}. Best is trial 5 with value: 0.6666666666666666.
# [I 2023-09-13 12:17:11,545] Trial 16 finished with value: 0.6666666666666666 and parameters: {'model': 'logistic', 'C': 12.895198183555987}. Best is trial 5 with value: 0.6666666666666666.
# [I 2023-09-13 12:17:11,565] Trial 17 finished with value: 0.6666666666666666 and parameters: {'model': 'logistic', 'C': 40.04492319813127}. Best is trial 5 with value: 0.6666666666666666.
# [I 2023-09-13 12:17:11,607] Trial 18 finished with value: 0.5714285714285715 and parameters: {'model': 'svm_linear', 'C': 7.4151225294219865}. Best is trial 5 with value: 0.6666666666666666.
# [I 2023-09-13 12:17:11,641] Trial 19 finished with value: 0.6666666666666666 and parameters: {'model': 'logistic', 'C': 36.73920165622506}. Best is trial 5 with value: 0.6666666666666666.
# Best Hyperparameters from Optuna: {'model': 'logistic', 'C': 64.73780655653773}
# Best Validation Set Accuracy: 0.6666666666666666
# Test Set Accuracy: 0.631578947368421

# %%
yi,xi,h,_ = dataset[0:3]
yi_hat, xi_hat = net(yi)

utils.vis_data_est(yi[0,0][0:500], modified_tensor[0:500])
utils.vis_data_est(yi[0,0][0:500], yi_hat[0,0][0:500])


print(len(padded_tensor))
print(len(yi[0,0]))
utils.vis_data(padded_tensor[0:500])
#utils.vis_data(b)
utils.vis_filters(h)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 yi,xi,h,_ = dataset[0:3]
#       2 yi_hat, xi_hat = net(yi)
#       4 utils.vis_data_est(yi[0,0][0:500], modified_tensor[0:500])
#
# NameError: name 'dataset' is not defined

# %%
plt.scatter(cur_snr_list,x_f1_score, marker='o')
plt.xlabel('SNR')
plt.ylabel('x F1 score')
plt.title('')
plt.grid(True)
plt.show()

# %%
plt.scatter(cur_snr_list,y_f1_score, marker='o')
plt.xlabel('SNR')
plt.ylabel('y F1 score')
plt.title('')
plt.grid(True)
plt.show()

# %%
plt.scatter(cur_snr_list, y_hat_f1_score, marker='o')
plt.scatter(cur_snr_list,y_f1_score, marker='*')
plt.xlabel('SNR')
plt.ylabel('F1 score')
plt.legend(['y_hat','y'])
plt.title('F1 score before and after denoising')
plt.grid(True)
plt.show()

# %%
import pandas as pd
data = {'SNR': cur_snr_list, 'F1 score y_hat': y_hat_f1_score, 'F1 score y': y_f1_score}
df = pd.DataFrame(data)

# Specify the file name
csv_filename = 'simulated_behave_data_comperison.csv'

# Save the DataFrame to a CSV file
df.to_csv(csv_filename, index=False)

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.pandas.read_csv('results\simulated_behave_data_comperison_dialated.csv')

# Group the data by SNR and calculate mean and variance
grouped = df.groupby('SNR').agg({'F1 score y_hat': ['mean', 'std','count']})

# Extract the mean and variance values
means = grouped['F1 score y_hat']['mean']
std = grouped['F1 score y_hat']['std']
standard_error = std/grouped['F1 score y_hat']['count']

# Create a bar plot with error bars
plt.errorbar(means.index, means, yerr=standard_error, fmt='o', capsize=4)
# Group the data by SNR and calculate mean and variance
grouped = df.groupby('SNR').agg({'F1 score y': ['mean', 'std','count']})

# Extract the mean and variance values
means = grouped['F1 score y']['mean']
std = grouped['F1 score y']['std']
standard_error = std/grouped['F1 score y']['count']

# Create a bar plot with error bars
plt.errorbar(means.index, means, yerr=standard_error, fmt='o', capsize=4)

# Add labels and title
plt.xlabel('SNR')
plt.ylabel('Mean Values')
plt.title('Mean Values with standard Error Bars')
plt.legend(['y_hat','y'])

# Show the plot
plt.show()

# %%
x_const = None
for cur_snr, cur_lam in snr_list:
    net_hyp = {"T": 200,                 # number of encoder unfolding
            "L": 10,                  # 1/L is the step size in the encoder
            "C": 2,                 # number of filters
            "K": 18,                  # legnth of the filters
            "lam": cur_lam,
            "device": device
            }
    data_hyp ={"J": J, "N": N, "K": K, "C": C, "s": s, "x_mean": x_mean,
            "x_std": x_std, "SNR": cur_snr, "device": device}
    dataset = Simulate_Dataset.SimulatedDataset1D(data_hyp,x_const,one_kernel = True)
    net = Model.CRsAE1D(net_hyp)
    net.load_state_dict(torch.load(f'pretrained_on_simulated_data\snr_{snr_list[0][0]}.pth'))
    with torch.no_grad():
      y,x,_,_ = dataset[:]
      x_const = x
      x = torch.sum(x, dim=1, keepdim=True)
      y_hat, x_hat = net(y)
      #utils.vis_data_est(y[1,0], y_hat[1,0])
      x_hat = torch.sum(x_hat, dim=1, keepdim=True)
      y = y.squeeze(dim = 1)
      b = x[0,0] > 0
      x = x.squeeze(dim = 1)
      y_hat = y_hat.squeeze(dim = 1)
      x_hat = x_hat.squeeze(dim = 1)
      padding_begining = 15
      padding_end = 19
      # Perform the padding
      padded_tensor = torch.cat([torch.zeros(padding_begining).to(device), torch.tensor(b),torch.zeros(padding_end).to(device)])
      modified_tensor = torch.zeros_like(padded_tensor).to(device)
      indices_of_ones = torch.nonzero(padded_tensor).squeeze()

      for index in indices_of_ones:
        modified_tensor[index-1:index+3] = 1
          
yi,xi,h,_ = dataset[0:3]
yi_hat, xi_hat = net(yi)

utils.vis_data_est(yi[0,0][0:500], modified_tensor[0:500])
utils.vis_data_est(yi[0,0][0:500], yi_hat[0,0][0:500])


print(len(padded_tensor))
print(len(yi[0,0]))
utils.vis_data(padded_tensor[0:500])
#utils.vis_data(b)
utils.vis_filters(h)
# Out:
# C:\Users\yonatan.kle\AppData\Local\Temp\ipykernel_4676\2960374484.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   padded_tensor = torch.cat([torch.zeros(padding_begining).to(device), torch.tensor(b),torch.zeros(padding_end).to(device)])
# 3030
# 3030

# %%
dataset_behave = create_behave_dataset_matrix(y_hat,modified_tensor,device = device)
X = dataset_behave.data.cpu()
b = dataset_behave.label.cpu()
print(len(b))
print(len(X))
kf = KFold(n_splits=10, shuffle=False)
test_accuracy_list = []
print("running tuna study on metric")
for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    b_train, b_test = b[train_index], b[test_index]
    X_train, X_val, b_train, b_val = train_test_split(X_train, b_train, test_size=0.1, shuffle=False)
    y_test = y[test_index]
    break
best_model = LogisticRegression(C=64.7, max_iter=1000)
best_model.fit(X_train, b_train)

# Evaluate the model on the test set
b_test_pred = best_model.predict(X_test)
test_accuracy = f1_score(b_test, b_test_pred)

plt.figure()
# Create subplots
plt.subplot(3, 1, 1)
plt.plot(b_test.T, label='ground truth')
plt.subplot(3, 1, 2)
plt.plot(b_test_pred.mT, label='predicted')
plt.subplot(3, 1, 3)
plt.plot(X_test.mT[0], label='signal')
# Show or save the figure
plt.tight_layout()  # Adjust subplot spacing for clarity
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 2
#       1 dataset_behave = create_behave_dataset_matrix(y_hat,modified_tensor,device = device)
# ----> 2 X = dataset_behave.data.cpu()
#       3 b = dataset_behave.label.cpu()
#       4 print(len(b))
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
dataset_behave = create_behave_dataset_matrix(y,modified_tensor,device = device)
X = dataset_behave.data.cpu()
b = dataset_behave.label.cpu()
kf = KFold(n_splits=10, shuffle=False)
test_accuracy_list = []
print("running tuna study on metric")
for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    b_train, b_test = b[train_index], b[test_index]
    X_train, X_val, b_train, b_val = train_test_split(X_train, b_train, test_size=0.1, shuffle=False)
    y_test = y[test_index]
    break
best_model = LogisticRegression(C=64.7, max_iter=1000)
best_model.fit(X_train, b_train)

# Evaluate the model on the test set
b_test_pred = best_model.predict(X_test)
test_accuracy = f1_score(b_test, b_test_pred)

plt.figure()
# Create subplots
plt.subplot(3, 1, 1)
plt.plot(b_test.T, label='ground truth')
plt.subplot(3, 1, 2)
plt.plot(b_test_pred.T, label='predicted')
plt.subplot(3, 1, 3)
plt.plot(X_test.mT[0], label='signal')
# Show or save the figure
plt.tight_layout()  # Adjust subplot spacing for clarity
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 2
#       1 dataset_behave = create_behave_dataset_matrix(y,modified_tensor,device = device)
# ----> 2 X = dataset_behave.data.cpu()
#       3 b = dataset_behave.label.cpu()
#       4 kf = KFold(n_splits=10, shuffle=False)
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
    print(len(X_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(len(X_test))
#       2 plt.figure()
#       3 # Create subplots
#
# NameError: name 'X_test' is not defined
