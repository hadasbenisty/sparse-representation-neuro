# %%
import torch
import torch.nn.functional as F
import numpy as np                 # import numpy
import matplotlib.pyplot as plt    # import matplotlib
from torch.utils.data import Dataset, DataLoader,random_split
import torch.optim as optim
from tqdm import tqdm
import h5py
import scipy
from scipy.signal import find_peaks
from IPython.display import Image
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
import optuna

import utils
import Model
import Simulate_Dataset

# Set a random seed for PyTorch
seed = 42
torch.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False


use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

# %%
# dataset parameters
fs = 1000                     # sampling frequency in Hz
data_dur =  3*63                 # data duration in s
actpot_dur = 5                   # action potential length in ms
window_dur = 3                   # window dutation in s
C = 1                              # number of neurons
s = 40                              # number of appearance of each neuron in each window
x_mean = 2                         # code amplitude mean
x_std = 0.1                         # code amplitude std
noise_std = 0.1
snr = 20

K = int(actpot_dur * fs / 1000) # filter legnth
N = int(window_dur * fs)        # example duration
J = int(data_dur / window_dur)  # number of examples

# data parameters
data_hyp ={"J": J, "N": N, "K": K, "C": C, "s": s, "x_mean": x_mean,
           "x_std": x_std, "SNR": snr, "device": device}

print("filter length:", K)
print("example duration:", N)
print("number of examples:", J)
# Out:
# filter length: 5
# example duration: 3000
# number of examples: 63

# %%
# fill in the gaps
net_hyp = {"T": 200,                 # number of encoder unfolding
           "L": 10,                  # 1/L is the step size in the encoder
           "C": 1,                 # number of filters
           "K": 18,                  # legnth of the filters
           "lam": 0.2,
           "device": device
           }

net = Model.CRsAE1D(net_hyp)

# training parameters
train_hyp = {"batch_size": 8, "num_epochs": 12, "lr": 1e-2, "shuffle": True}
# criterion
criterion = torch.nn.MSELoss()
# optimizer
optimizer = optim.Adam(net.parameters(), lr=train_hyp["lr"], eps=1e-3)

# %%
snr_list = np.linspace(-10,50,13)
print(snr_list)
# Out:
# [-10.  -5.   0.   5.  10.  15.  20.  25.  30.  35.  40.  45.  50.]

# %%
def f1_score(label, pred):
  label = np.array(label.cpu())
  true_positives = np.sum((pred == 1) & (label == 1))
  all_positives = np.sum(label == 1)
  predicted_positives = np.sum(pred == 1)

  precision = true_positives / predicted_positives if predicted_positives > 0 else 0.0
  recall = true_positives / all_positives if all_positives > 0 else 0.0

  f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0
  return f1_score

def check_naive_classifiers(signal, label, k=10):
    dataset_behave = create_behave_dataset_matrix(signal,label,device = device)
    X = dataset_behave.data.cpu()
    y = dataset_behave.label.cpu()

    kf = KFold(n_splits=k, shuffle=False)
    test_accuracy_list = []
    print("running tuna study on metric")
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, shuffle=False)

        def objective(trial):
            # Define hyperparameter search space
            model_type = trial.suggest_categorical('model', ['svm_linear', 'svm_rbf', 'svm_poly', 'logistic'])
            C = trial.suggest_float('C', 0.01, 100, log=True)
            degree = trial.suggest_int('degree', 2, 15) if model_type == 'svm_poly' else None

            if model_type.startswith('svm'):
                if model_type == 'svm_linear':
                    svm_classifier = svm.SVC(C=C, kernel='linear')
                elif model_type == 'svm_rbf':
                    svm_classifier = svm.SVC(C=C, kernel='rbf')
                else:
                    svm_classifier = svm.SVC(C=C, kernel='poly', degree=degree)
                svm_classifier.fit(X_train, y_train)
                y_val_pred = svm_classifier.predict(X_val)
                val_accuracy = f1_score(y_val, y_val_pred)
            else:
                logistic_classifier = LogisticRegression(C=C, max_iter=1000)
                logistic_classifier.fit(X_train, y_train)
                y_val_pred = logistic_classifier.predict(X_val)
                val_accuracy = f1_score(y_val, y_val_pred)

            return val_accuracy

        # Create an Optuna study
        study = optuna.create_study(direction='maximize')
        study.optimize(objective, n_trials=20)

        # Get the best trial
        best_trial = study.best_trial
        best_params = best_trial.params
        best_score = best_trial.value

        # Train the best model on the entire training set
        if best_params['model'].startswith('svm'):
            best_model = svm.SVC(C=best_params['C'], kernel=best_params['model'][4:])
        else:
            best_model = LogisticRegression(C=best_params['C'], max_iter=1000)
        best_model.fit(X_train, y_train)

        # Evaluate the model on the test set
        y_test_pred = best_model.predict(X_test)
        test_accuracy = f1_score(y_test, y_test_pred)

        print("Best Hyperparameters from Optuna:", best_params)
        print("Best Validation Set Accuracy:", best_score)
        print("Test Set Accuracy:", test_accuracy)
        test_accuracy_list.append(test_accuracy)

    return np.mean(test_accuracy_list)


class create_behave_dataset_matrix(Dataset):
    def __init__(self, x,label,device):
        self.label = label
        chunks = torch.split(x, 1, dim=1)
        # Concatenating the chunks along the first dimension
        self.data = x.T

    def __len__(self):
        return len(self.label)

    def __getitem__(self, idx):
        return  self.data[idx], self.label[idx]

# %%
snr_list = [(10,0.15),(15,0.15),(20,0.1),(25,0.05),(30,0.05),(35,0.1),(40,0),(45,0),(50,0),(-10,0.9),(-5,0.5),(0,0.3),(5,0.25)]
#snr_list = [(50,0)]

# %%
x_f1_score = []
y_f1_score = []
y_hat_f1_score = []
cur_snr_list = []
x_const = None

# %%
for itr in range(10):
  print(f"%%%%%%%%%%%%%%{itr}%%%%%%%%%%%%%%%%%")
  for cur_snr, cur_lam in snr_list:
    net_hyp = {"T": 200,                 # number of encoder unfolding
            "L": 10,                  # 1/L is the step size in the encoder
            "C": 2,                 # number of filters
            "K": 18,                  # legnth of the filters
            "lam": cur_lam,
            "device": device
            }
    data_hyp ={"J": J, "N": N, "K": K, "C": C, "s": s, "x_mean": x_mean,
            "x_std": x_std, "SNR": cur_snr, "device": device}
    dataset = Simulate_Dataset.SimulatedDataset1D(data_hyp,x_const,one_kernel = True)
    net = Model.CRsAE1D(net_hyp)
    net.load_state_dict(torch.load(f'pretrained_on_simulated_data\snr_{snr_list[0][0]}.pth'))
    with torch.no_grad():
      y,x,_,_ = dataset[:]
      x_const = x
      x = torch.sum(x, dim=1, keepdim=True)
      y_hat, x_hat = net(y)
      #utils.vis_data_est(y[1,0], y_hat[1,0])
      x_hat = torch.sum(x_hat, dim=1, keepdim=True)
      y = y.squeeze(dim = 1)
      b = x[0,0] > 0
      x = x.squeeze(dim = 1)
      y_hat = y_hat.squeeze(dim = 1)
      x_hat = x_hat.squeeze(dim = 1)
      padding_begining = 7
      padding_end = 10
      # Perform the padding
      padded_tensor = torch.cat([torch.zeros(padding_begining).to(device), torch.tensor(b),torch.zeros(padding_end).to(device)])
      modified_tensor = torch.zeros_like(padded_tensor).to(device)
      indices_of_ones = torch.nonzero(padded_tensor).squeeze()

      for index in indices_of_ones:
        modified_tensor[index-1:index+3] = 1



    x_accuracy = []
    y_accuracy = []
    y_hat_accuracy = []
    print(f"For SNR = {cur_snr}")
    print("On x")
    x_accuracy.append(check_naive_classifiers(x, b))
    print("On y")
    y_accuracy.append(check_naive_classifiers(y, modified_tensor))
    print("On y_hat")
    y_hat_accuracy.append(check_naive_classifiers(y_hat, modified_tensor))

    cur_snr_list.append(cur_snr)
    x_f1_score.append(max(x_accuracy))
    y_f1_score.append(max(y_accuracy))
    y_hat_f1_score.append(max(y_hat_accuracy))

  # reset x for new study
  x_const = None
# Out:
# %%%%%%%%%%%%%%0%%%%%%%%%%%%%%%%%
# 8it [00:00,  9.63it/s]
# 8it [00:01,  7.32it/s]
# 8it [00:01,  5.40it/s]
# 8it [00:01,  5.58it/s]
# 8it [00:01,  5.71it/s]
# 8it [00:01,  5.75it/s]
# 8it [00:01,  5.94it/s]
# 8it [00:01,  5.92it/s]
# 8it [00:01,  5.86it/s]
# 8it [00:01,  5.99it/s]
# C:\Users\yonatan.kle\AppData\Local\Temp\ipykernel_17584\2883642101.py:54: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   padded_tensor = torch.cat([torch.zeros(padding_begining).to(device), torch.tensor(b),torch.zeros(padding_end).to(device)])
# [I 2023-09-12 12:10:46,114] A new study created in memory with name: no-name-7814b72f-d881-4660-8a32-f4eadc15a06e
# [I 2023-09-12 12:10:46,184] Trial 0 finished with value: 1.0 and parameters: {'model': 'svm_rbf', 'C': 12.809504346735876}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,199] Trial 1 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.46728490209313595}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,208] Trial 2 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 3.1283492706423597}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,266] Trial 3 finished with value: 1.0 and parameters: {'model': 'svm_rbf', 'C': 2.72824793155237}. Best is trial 0 with value: 1.0.
# For SNR = 10
# On x
# running tuna study on metric
# [I 2023-09-12 12:10:46,341] Trial 4 finished with value: 0.6666666666666666 and parameters: {'model': 'svm_rbf', 'C': 0.24405311041486227}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,399] Trial 5 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 0.06096637487316371}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,461] Trial 6 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 0.017247026400804596}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,517] Trial 7 finished with value: 1.0 and parameters: {'model': 'svm_rbf', 'C': 36.521554179031966}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,535] Trial 8 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.3288155655849196}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,552] Trial 9 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 23.500145099250553}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,560] Trial 10 finished with value: 1.0 and parameters: {'model': 'svm_poly', 'C': 84.78742402928467, 'degree': 4}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,585] Trial 11 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 6.458147560403075}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,592] Trial 12 finished with value: 1.0 and parameters: {'model': 'svm_poly', 'C': 0.9256680606989552, 'degree': 15}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,618] Trial 13 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 10.882565549376375}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,626] Trial 14 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.9017320639410322}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,637] Trial 15 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 3.411878817788357}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,653] Trial 16 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 14.66069365874022}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,653] Trial 17 finished with value: 1.0 and parameters: {'model': 'svm_poly', 'C': 94.49379220245727, 'degree': 13}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,732] Trial 18 finished with value: 0.6666666666666666 and parameters: {'model': 'svm_rbf', 'C': 0.36816891361804716}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,742] Trial 19 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 5.4855299904343005}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,815] A new study created in memory with name: no-name-862a10d4-c25a-4c3b-9283-660fe42a3aee
# [I 2023-09-12 12:10:46,821] Trial 0 finished with value: 1.0 and parameters: {'model': 'svm_poly', 'C': 6.695709437576531, 'degree': 4}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,837] Trial 1 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.5331342918599682}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,837] Trial 2 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.36399877626107996}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,853] Trial 3 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 0.28622101265870936}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,853] Trial 4 finished with value: 1.0 and parameters: {'model': 'svm_poly', 'C': 0.29689806124703655, 'degree': 10}. Best is trial 0 with value: 1.0.
# [I 2023-09-12 12:10:46,853] Trial 5 finished with value: 1.0 and parameters: {'model': 'svm_poly', 'C':
finished with value: 0.8571428571428571 and parameters: {'model': 'svm_rbf', 'C': 0.33456345027020246}. Best is trial 0 with value: 0.8571428571428571.
# [I 2023-09-12 12:10:50,739] Trial 1 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 16.19766230929459}. Best is trial 1 with value: 1.0.
# [I 2023-09-12 12:10:50,745] Trial 2 finished with value: 1.0 and parameters: {'model': 'svm_poly', 'C': 0.33307706975459805, 'degree': 14}. Best is trial 1 with value: 1.0.
# [I 2023-09-12 12:10:50,754] Trial 3 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 3.9869589483788883}. Best is trial 1 with value: 1.0.
# [I 2023-09-12 12:10:50,754] Trial 4 finished with value: 1.0 and parameters: {'model': 'svm_poly', 'C': 18.169804333548964, 'degree': 8}. Best is trial 1 with value: 1.0.
# [I 2023-09-12 12:10:50,771] Trial 5 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.019038042083561805}. Best is trial 1 with value: 1.0.
# [I 2023-09-12 12:10:50,771] Trial 6 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 0.7071859583902658}. Best is trial 1 with value: 1.0.
# [I 2023-09-12 12:10:50,771] Trial 7 finished with value: 0.8571428571428571 and parameters: {'model': 'svm_poly', 'C': 0.0452164142172268, 'degree': 9}. Best is trial 1 with value: 1.0.
# [I 2023-09-12 12:10:50,789] Trial 8 finished with value: 1.0 and parameters: {'model': 'svm_poly', 'C': 0.8124936357908892, 'degree': 9}. Best is trial 1 with value: 1.0.
# [I 2023-09-12 12:10:50,789] Trial 9 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 1.423966740111629}. Best is trial 1 with value: 1.0.
# [I 2023-09-12 12:10:50,805] Trial 10 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 75.85198720703615}. Best is trial 1 with value: 1.0.
# Best Hyperparameters from Optuna: {'model': 'svm_linear', 'C': 2.29934019190273}
# Best Validation Set Accuracy: 1.0
# Test Set Accuracy: 1.0
# [I 2023-09-12 12:10:50,878] Trial 11 finished with value: 0.8571428571428571 and parameters: {'model': 'svm_rbf', 'C': 13.410766528357971}. Best is trial 1 with value: 1.0.
# [I 2023-09-12 12:10:50,888] Trial 12 finished with value: 0.8571428571428571 and parameters: {'model': 'logistic', 'C': 0.10732899420901307}. Best is trial 1 with value: 1.0.
# [I 2023-09-12 12:10:50,906] Trial 13 finished with value: 1.0 and parameters: {'model': 'svm_poly', 'C': 0.18204588416071965, 'degree': 14}. Best is trial 1 with value: 1.0.
# [I 2023-09-12 12:10:50,906] Trial 14 finished with value: 1.0 and parameters: {'model': 'svm_poly', 'C': 2.508080036713185, 'degree': 14}. Best is trial 1 with value: 1.0.
# [I 2023-09-12 12:10:50,922] Trial 15 finished with value: 1.0 and parameters: {'model': 'logistic', 'C': 5.640235021100732}. Best is trial 1 with value: 1.0.
# [I 2023-09-12 12:10:50,987] Trial 16 finished with value: 0.8571428571428571 and parameters: {'model': 'svm_rbf', 'C': 0.4737828300778161}. Best is trial 1 with value: 1.0.
# [I 2023-09-12 12:10:51,004] Trial 17 finished with value: 1.0 and parameters: {'model': 'svm_linear', 'C': 89.2022963261634}. Best is trial 1 with value: 1.0.
# [I 2023-09-12 12:10:51,004] Trial 18 finished with value: 1.0 and parameters: {'model': 'svm_poly', 'C': 1.5542884937315073, 'degree': 5}. Best is trial 1 with value: 1.0.
# [I 2023-09-12 12:10:51,024] Trial 19 finished with value: 0.8571428571428571 and parameters: {'model': 'logistic', 'C': 0.11305054808609931}. Best is trial 1 with value: 1.0.
# [I 2023-09-12 12:10:51,038] A new study created in memory with name: no-name-cb7b6a25-69a3-4842-ac9d-bb1de7e36725
# [I 2023-09-12 12:10:51,103] Trial 0 finished with value: 0.8571428571428571 and parameters: {'model': 'svm_rbf', 'C': 84.45095824962915}. Best is trial 0 with value: 0.8571428571428571.
# [I 2023-09-12 12:10:51,138] Trial 1 finished with value: 0.4 and parameters: {'model': 'svm_linear', 'C': 0.03556247199506147}. Best is trial 0 with value: 0.8571428571428571.
# [I 2023-09-12 12:10:51,155] Trial 2 finished with value: 0.875 and parameters: {'model': 'logistic', 'C': 33.103174960853316}. Best is trial 2 with value: 0.875.
# Best Hyperparameters from Optuna: {'model': 'logistic', 'C': 16.19766230929459}
# Best Validation Set Accuracy: 1.0
# Test Set Accuracy: 1.0
# On y
# running tuna study on metric
# [I 2023-09-12 12:10:51,221] Trial 3 finished with value: 0.8571428571428571 and parameters: {'model': 'svm_rbf', 'C': 62.852021353801355}. Best is trial 2 with value: 0.875.
# [I 2023-09-12 12:10:51,255] Trial 4 finished with value: 0.896551724137931 and parameters: {'model': 'svm_linear', 'C': 12.785814152304676}. Best is trial 4 with value: 0.896551724137931.
# [I 2023-09-12 12:10:51,444] Trial 5 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 2.3638603710111226, 'degree': 5}. Best is trial 4 with value: 0.896551724137931.
# [I 2023-09-12 12:10:51,600] Trial 6 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 0.02930637541312598, 'degree': 6}. Best is trial 4 with value: 0.896551724137931.
# [I 2023-09-12 12:10:51,625] Trial 7 finished with value: 0.7692307692307693 and parameters: {'model': 'svm_linear', 'C': 0.048920863476666285}. Best is trial 4 with value: 0.896551724137931.
# [I 2023-09-12 12:10:51,660] Trial 8 finished with value: 0.9333333333333333 and parameters: {'model': 'svm_linear', 'C': 46.54347965931197}. Best is trial 8 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:51,720] Trial 9 finished with value: 0.8571428571428571 and parameters: {'model': 'svm_rbf', 'C': 9.126550870731045}. Best is trial 8 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:51,747] Trial 10 finished with value: 0.8571428571428571 and parameters: {'model': 'logistic', 'C': 0.8017760173854944}. Best is trial 8 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:51,773] Trial 11 finished with value: 0.896551724137931 and parameters: {'model': 'svm_linear', 'C': 9.270247339075716}. Best is trial 8 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:51,808] Trial 12 finished with value: 0.9333333333333333 and parameters: {'model': 'svm_linear', 'C': 22.736759758196026}. Best is trial 8 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:51,842] Trial 13 finished with value: 0.9032258064516129 and parameters: {'model': 'svm_linear', 'C': 90.46294481230201}. Best is trial 8 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:51,881] Trial 14 finished with value: 0.9333333333333333 and parameters: {'model': 'svm_linear', 'C': 24.79524607710364}. Best is trial 8 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:51,909] Trial 15 finished with value: 0.9032258064516129 and parameters: {'model': 'svm_linear', 'C': 4.08142782259802}. Best is trial 8 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:51,947] Trial 16 finished with value: 0.9333333333333333 and parameters: {'model': 'svm_linear', 'C': 29.918335294270154}. Best is trial 8 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:52,114] Trial 17 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 0.9877883020410035, 'degree': 15}. Best is trial 8 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:52,138] Trial 18 finished with value: 0.896551724137931 and parameters: {'model': 'logistic', 'C': 4.102481938797115}. Best is trial 8 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:52,186] Trial 19 finished with value: 0.9333333333333333 and parameters: {'model': 'svm_linear', 'C': 26.55796221364049}. Best is trial 8 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:52,223] A new study created in memory with name: no-name-0ad84e82-5755-4a5f-b7df-823a154f7eec
# [I 2023-09-12 12:10:52,282] Trial 0 finished with value: 0.7692307692307693 and parameters: {'model': 'svm_rbf', 'C': 32.89109339118166}. Best is trial 0 with value: 0.7692307692307693.
# Best Hyperparameters from Optuna: {'model': 'svm_linear', 'C': 46.54347965931197}
# Best Validation Set Accuracy: 0.9333333333333333
# Test Set Accuracy: 0.8421052631578948
# [I 2023-09-12 12:10:52,503] Trial 1 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 25.36317805197389, 'degree': 9}. Best is trial 0 with value: 0.7692307692307693.
# [I 2023-09-12 12:10:52,555] Trial 2 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 0.03929092519637193}. Best is trial 0 with value: 0.7692307692307693.
# [I 2023-09-12 12:10:52,788] Trial 3 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 66.46116334275955, 'degree': 13}. Best is trial 0 with value: 0.7692307692307693.
# [I 2023-09-12 12:10:52,816] Trial 4 finished with value: 0.9333333333333333 and parameters: {'model': 'logistic', 'C': 30.26971816132512}. Best is trial 4 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:52,823] Trial 5 finished with value: 0.47619047619047616 and parameters: {'model': 'logistic', 'C': 0.2792904332076205}. Best is trial 4 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:52,874] Trial 6 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 0.010293155046671658}. Best is trial 4 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:53,080] Trial 7 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 19.869886152934154, 'degree': 13}. Best is trial 4 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:53,089] Trial 8 finished with value: 0.8571428571428571 and parameters: {'model': 'logistic', 'C': 0.5738039436503081}. Best is trial 4 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:53,106] Trial 9 finished with value: 0.896551724137931 and parameters: {'model': 'svm_linear', 'C': 0.1033959705809734}. Best is trial 4 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:53,138] Trial 10 finished with value: 0.9333333333333333 and parameters: {'model': 'logistic', 'C': 3.4154951391674273}. Best is trial 4 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:53,158] Trial 11 finished with value: 0.9333333333333333 and parameters: {'model': 'logistic', 'C': 3.2098097815417956}. Best is trial 4 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:53,173] Trial 12 finished with value: 0.9333333333333333 and parameters: {'model': 'logistic', 'C': 3.8666161096478997}. Best is trial 4 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:53,190] Trial 13 finished with value: 0.9333333333333333 and parameters: {'model': 'logistic', 'C': 3.621114686606552}. Best is trial 4 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:53,224] Trial 14 finished with value: 0.896551724137931 and parameters: {'model': 'svm_linear', 'C': 10.815289976825722}. Best is trial 4 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:53,258] Trial 15 finished with value: 0.8484848484848485 and parameters: {'model': 'logistic', 'C': 82.90128662025982}. Best is trial 4 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:53,279] Trial 16 finished with value: 0.896551724137931 and parameters: {'model': 'logistic', 'C': 7.971014487279217}. Best is trial 4 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:53,294] Trial 17 finished with value: 0.8571428571428571 and parameters: {'model': 'logistic', 'C': 1.4739386777589192}. Best is trial 4 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:53,315] Trial 18 finished with value: 0.896551724137931 and parameters: {'model': 'svm_linear', 'C': 1.3374899587183877}. Best is trial 4 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:53,340] Trial 19 finished with value: 0.896551724137931 and parameters: {'model': 'logistic', 'C': 9.278545534254377}. Best is trial 4 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:53,364] A new study created in memory with name: no-name-ae7c9d30-16b7-4f2c-b573-f17950170245
# [I 2023-09-12 12:10:53,549] Trial 0 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 0.019867356140969, 'degree': 12}. Best is trial 0 with value: 0.0.
# Best Hyperparameters from Optuna: {'model': 'logistic', 'C': 30.26971816132512}
# Best Validation Set Accuracy: 0.9333333333333333
# Test Set Accuracy: 0.8196721311475409
# [I 2023-09-12 12:10:53,748] Trial 1 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 5.029177094706659, 'degree': 7}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:10:53,963] Trial 2 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 0.5205910927758177, 'degree': 14}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:10:54,023] Trial 3 finished with value: 0.8571428571428571 and parameters: {'model': 'svm_rbf', 'C': 11.217949190661097}. Best is trial 3 with value: 0.8571428571428571.
# [I 2023-09-12 12:10:54,203] Trial 4 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 0.011665715923382912, 'degree': 14}. Best is trial 3 with value: 0.8571428571428571.
# [I 2023-09-12 12:10:54,232] Trial 5 finished with value: 0.8275862068965517 and parameters: {'model': 'svm_linear', 'C': 25.894451138999653}. Best is trial 3 with value: 0.8571428571428571.
# [I 2023-09-12 12:10:54,399] Trial 6 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 0.017433538456923598, 'degree': 13}. Best is trial 3 with value: 0.8571428571428571.
# [I 2023-09-12 12:10:54,428] Trial 7 finished with value: 0.8666666666666666 and parameters: {'model': 'svm_linear', 'C': 4.522154676338499}. Best is trial 7 with value: 0.8666666666666666.
# [I 2023-09-12 12:10:54,473] Trial 8 finished with value: 0.8571428571428571 and parameters: {'model': 'svm_rbf', 'C': 9.668591602311817}. Best is trial 7 with value: 0.8666666666666666.
# [I 2023-09-12 12:10:54,507] Trial 9 finished with value: 0.9333333333333333 and parameters: {'model': 'svm_linear', 'C': 1.1992005563012067}. Best is trial 9 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:54,526] Trial 10 finished with value: 0.8571428571428571 and parameters: {'model': 'logistic', 'C': 0.48824180402209316}. Best is trial 9 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:54,550] Trial 11 finished with value: 0.8571428571428571 and parameters: {'model': 'svm_linear', 'C': 2.0394526660146846}. Best is trial 9 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:54,593] Trial 12 finished with value: 0.8387096774193549 and parameters: {'model': 'svm_linear', 'C': 97.42426238855222}. Best is trial 9 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:54,608] Trial 13 finished with value: 0.9333333333333333 and parameters: {'model': 'svm_linear', 'C': 1.5471636124661456}. Best is trial 9 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:54,642] Trial 14 finished with value: 0.9333333333333333 and parameters: {'model': 'svm_linear', 'C': 0.8930169372063358}. Best is trial 9 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:54,659] Trial 15 finished with value: 0.5454545454545454 and parameters: {'model': 'logistic', 'C': 0.20722691723946632}. Best is trial 9 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:54,684] Trial 16 finished with value: 0.8571428571428571 and parameters: {'model': 'svm_linear', 'C': 0.15833670428218488}. Best is trial 9 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:54,709] Trial 17 finished with value: 0.8571428571428571 and parameters: {'model': 'svm_linear', 'C': 1.9048122639084837}. Best is trial 9 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:54,737] Trial 18 finished with value: 0.896551724137931 and parameters: {'model': 'svm_linear', 'C': 1.7159549029755043}. Best is trial 9 with value: 0.9333333333333333.
# [I 2023-09-12 12:10:54,747] Trial 19 finished with value: 0.4 and parameters: {'model': 'logistic', 'C': 0.1338380392290464}. Best is trial 9 with value: 0.9333333333333333.
# ...
# [I 2023-09-12 12:28:01,353] Trial 9 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 0.3521236898772735, 'degree': 3}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:01,388] Trial 10 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 0.012352535666558497}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:01,400] Trial 11 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 9.092320408020367}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:01,557] Trial 12 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 7.870833543703131}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:01,589] Trial 13 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 7.7410384443339755}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:01,604] Trial 14 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.2053935415841998}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:01,745] Trial 15 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 97.0357094713007}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:02,028] Trial 16 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 25.68623386189047, 'degree': 15}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:02,139] Trial 17 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 17.254411397173698}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:02,296] Trial 18 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 4.451337233504615}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:02,312] Trial 19 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 2.01856298329899}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:02,469] A new study created in memory with name: no-name-4e4634ab-fdaa-4f15-84a3-fe437678cb17
# [I 2023-09-12 12:28:02,610] Trial 0 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 84.12111658227063}. Best is trial 0 with value: 0.0.
# Best Hyperparameters from Optuna: {'model': 'svm_rbf', 'C': 0.8291991392037659}
# Best Validation Set Accuracy: 0.0
# Test Set Accuracy: 0.0
# [I 2023-09-12 12:28:02,751] Trial 1 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 0.11134746847251947}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:02,909] Trial 2 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 0.1706441906526322}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:02,924] Trial 3 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.46679511920115746}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:03,176] Trial 4 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 7.607089239563871, 'degree': 15}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:03,270] Trial 5 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 17.069093399243705}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:03,292] Trial 6 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.2634040758080587}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:03,537] Trial 7 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 79.09173993031749, 'degree': 6}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:03,741] Trial 8 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 0.11345127692790695, 'degree': 4}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:03,946] Trial 9 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 0.0532572360937956, 'degree': 8}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:04,055] Trial 10 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 0.01037540247307076}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:04,213] Trial 11 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 2.0090548328072297}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:04,354] Trial 12 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 3.2297356673695266}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:04,511] Trial 13 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 0.8947272875741644}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:04,700] Trial 14 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 43.512692719019505}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:04,857] Trial 15 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 24.425581664935446}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:05,014] Trial 16 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 6.922897791140644}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:05,171] Trial 17 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 75.78901601084134}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:05,218] Trial 18 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 0.5369660901667931}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:05,234] Trial 19 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 2.3494631644121955}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:05,390] A new study created in memory with name: no-name-9e1a31b7-577b-496c-aa2f-c24dd327d3b3
# [I 2023-09-12 12:28:05,406] Trial 0 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 0.017450563995099134}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:05,422] Trial 1 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.9696290778581299}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:05,438] Trial 2 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 8.681701162387588}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:05,516] Trial 3 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 7.764683152548635}. Best is trial 0 with value: 0.0.
# Best Hyperparameters from Optuna: {'model': 'svm_rbf', 'C': 84.12111658227063}
# Best Validation Set Accuracy: 0.0
# Test Set Accuracy: 0.0
# [I 2023-09-12 12:28:05,673] Trial 4 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 1.7259191478478895}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:05,831] Trial 5 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 19.92469587655139}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:06,019] Trial 6 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 0.025299828098239215, 'degree': 5}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:06,035] Trial 7 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 12.483856095736867}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:06,271] Trial 8 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 2.903802812743762, 'degree': 7}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:06,286] Trial 9 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 84.9844006009397}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:06,302] Trial 10 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 0.011568001210953138}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:06,334] Trial 11 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 0.2318406619517839}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:06,349] Trial 12 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.22312643137448723}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:06,380] Trial 13 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 0.3422805496755593}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:06,412] Trial 14 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 0.04827247298767892}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:06,428] Trial 15 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.05876992067025196}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:06,602] Trial 16 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 0.6956536659175094}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:06,821] Trial 17 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 0.010308458524829275, 'degree': 15}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:06,852] Trial 18 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 0.11378086484292822}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:06,868] Trial 19 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.565232225156012}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:06,902] A new study created in memory with name: no-name-8832c837-fc6f-42d2-9ca0-c680a39acd37
# [I 2023-09-12 12:28:07,025] Trial 0 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 0.04354093804050819}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:07,041] Trial 1 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.40090664630575995}. Best is trial 0 with value: 0.0.
# Best Hyperparameters from Optuna: {'model': 'svm_linear', 'C': 0.017450563995099134}
# Best Validation Set Accuracy: 0.0
# Test Set Accuracy: 0.0
# [I 2023-09-12 12:28:07,182] Trial 2 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 0.2537810201424603}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:07,198] Trial 3 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 6.133992614891953}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:07,230] Trial 4 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 3.019280197766432}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:07,481] Trial 5 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 0.11658575232684501, 'degree': 8}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:07,607] Trial 6 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 0.03165361025388584}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:07,780] Trial 7 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 37.12725125305597}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:07,906] Trial 8 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 0.22710720584024688}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:07,921] Trial 9 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 6.891436644381313}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:08,157] Trial 10 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 0.013948689005100113, 'degree': 15}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:08,172] Trial 11 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.6480190788708404}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:08,188] Trial 12 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.058293607430806645}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:08,298] Trial 13 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 0.010002729922990986}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:08,424] Trial 14 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 0.5939139222251107}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:08,440] Trial 15 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.06268283556368491}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:08,518] Trial 16 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 0.14936306665037113, 'degree': 2}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:08,550] Trial 17 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 0.03336067248179307}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:08,565] Trial 18 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 1.5212927013699673}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:08,707] Trial 19 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 0.4797935446164695}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:08,833] A new study created in memory with name: no-name-e539eadc-99d1-4c3f-8294-30464bcc1e5a
# [I 2023-09-12 12:28:08,848] Trial 0 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.11018510651334691}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:08,989] Trial 1 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 77.91749831586989}. Best is trial 0 with value: 0.0.
# Best Hyperparameters from Optuna: {'model': 'svm_rbf', 'C': 0.04354093804050819}
# Best Validation Set Accuracy: 0.0
# Test Set Accuracy: 0.0
# [I 2023-09-12 12:28:09,241] Trial 2 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 14.134283990197806, 'degree': 7}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:09,272] Trial 3 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 0.1654022282941602}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:09,508] Trial 4 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 0.06589701408595916, 'degree': 10}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:09,649] Trial 5 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 6.8946916518448615}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:09,712] Trial 6 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 0.020665373978050215, 'degree': 2}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:09,932] Trial 7 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 0.0360548068577054, 'degree': 13}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:10,136] Trial 8 finished with value: 0.0 and parameters: {'model': 'svm_poly', 'C': 0.03585554133431089, 'degree': 6}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:10,152] Trial 9 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 6.595179496973521}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:10,168] Trial 10 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.45687929114963666}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:10,325] Trial 11 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 85.79061850123827}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:10,340] Trial 12 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.836599927500952}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:10,481] Trial 13 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 0.19976463353417226}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:10,529] Trial 14 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 2.481311223423243}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:10,686] Trial 15 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 55.40411838754217}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:10,701] Trial 16 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 0.011231920162092502}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:10,843] Trial 17 finished with value: 0.0 and parameters: {'model': 'svm_rbf', 'C': 1.9218551005274915}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:10,858] Trial 18 finished with value: 0.0 and parameters: {'model': 'logistic', 'C': 32.0639961647083}. Best is trial 0 with value: 0.0.
# [I 2023-09-12 12:28:11,000] Trial 19 finished with value: 0.0 and parameters: {'model': 'svm_linear', 'C': 25.36551986621046}. Best is trial 0 with value: 0.0.
# Best Hyperparameters from Optuna: {'model': 'logistic', 'C': 0.11018510651334691}
# Best Validation Set Accuracy: 0.0
# Test Set Accuracy: 0.0
# 8it [00:01,  5.48it/s]
# 8it [00:01,  5.59it/s]
# 7it [00:01,  5.75it/s]

# %%
yi,xi,h,_ = dataset[0:3]
yi_hat, xi_hat = net(yi)

utils.vis_data_est(yi[0,0][0:500], modified_tensor[0:500])
utils.vis_data_est(yi[0,0][0:500], yi_hat[0,0][0:500])


print(len(padded_tensor))
print(len(yi[0,0]))
utils.vis_data(padded_tensor[0:500])
#utils.vis_data(b)
utils.vis_filters(h)

# %%
plt.scatter(cur_snr_list,x_f1_score, marker='o')
plt.xlabel('SNR')
plt.ylabel('x F1 score')
plt.title('')
plt.grid(True)
plt.show()

# %%
plt.scatter(cur_snr_list,y_f1_score, marker='o')
plt.xlabel('SNR')
plt.ylabel('y F1 score')
plt.title('')
plt.grid(True)
plt.show()

# %%
plt.scatter(cur_snr_list, y_hat_f1_score, marker='o')
plt.scatter(cur_snr_list,y_f1_score, marker='*')
plt.xlabel('SNR')
plt.ylabel('F1 score')
plt.legend(['y_hat','y'])
plt.title('F1 score before and after denoising')
plt.grid(True)
plt.show()

# %%
import pandas as pd
data = {'SNR': cur_snr_list, 'F1 score y_hat': y_hat_f1_score, 'F1 score y': y_f1_score}
df = pd.DataFrame(data)

# Specify the file name
csv_filename = 'simulated_behave_data_comperison.csv'

# Save the DataFrame to a CSV file
df.to_csv(csv_filename, index=False)

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.pandas.read_csv('simulated_behave_data_comperison.csv')

# Group the data by SNR and calculate mean and variance
grouped = df.groupby('SNR').agg({'F1 score y_hat': ['mean', 'std','count']})

# Extract the mean and variance values
means = grouped['F1 score y_hat']['mean']
std = grouped['F1 score y_hat']['std']
standard_error = std/grouped['F1 score y_hat']['count']

# Create a bar plot with error bars
plt.errorbar(means.index, means, yerr=standard_error, fmt='o', capsize=4)
# Group the data by SNR and calculate mean and variance
grouped = df.groupby('SNR').agg({'F1 score y': ['mean', 'std','count']})

# Extract the mean and variance values
means = grouped['F1 score y']['mean']
std = grouped['F1 score y']['std']
standard_error = std/grouped['F1 score y']['count']

# Create a bar plot with error bars
plt.errorbar(means.index, means, yerr=standard_error, fmt='o', capsize=4)

# Add labels and title
plt.xlabel('SNR')
plt.ylabel('Mean Values')
plt.title('Mean Values with standard Error Bars')
plt.legend(['y_hat','y'])

# Show the plot
plt.show()
